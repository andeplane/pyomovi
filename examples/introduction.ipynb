# %% [markdown]
# # Introduction

# %%
import pyomovi

# %%
w = pyomovi.ExampleWidget()
w
# Out:
# ExampleWidget()

# %%
import time
import numpy as np

positions = 100 * np.random.rand(1000000, 3)
start = time.time()
w.particle_positions = positions
end = time.time()
print(f"Updated spending {end-start} seconds.")
# Out:
# Updated spending 0.0028192996978759766 seconds.
